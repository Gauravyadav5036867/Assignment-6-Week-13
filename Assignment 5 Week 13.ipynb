# %%
#Question 1


To calculate the Pearson correlation coefficient between the amount of time students spend studying for an exam and their final exam scores, you would typically follow these steps:

Collect data: Gather data on the amount of time each student spends studying for the exam and their corresponding final exam scores.

1. Compute the mean of each variable: Calculate the mean (average) of the study time and the mean of the exam scores.

2. Calculate the covariance: Compute the covariance between the study time and exam scores. Covariance measures how two variables change together.

3. Calculate the standard deviation of each variable: Compute the standard deviation of the study time and the standard deviation of the exam scores.

4. Calculate the Pearson correlation coefficient: Divide the covariance by the product of the standard deviations of the two variables.

The formula for the Pearson correlation coefficient (r) is:

�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(x 
i
​
 − 
x
ˉ
 ) 
2
 ∑(y 
i
​
 − 
y
ˉ
​
 ) 
2
 
​
 
∑(x 
i
​
 − 
x
ˉ
 )(y 
i
​
 − 
y
ˉ
​
 )
​


Where:

�
�
x 
i
​
  and 
�
�
y 
i
​
  are individual data points,
�
ˉ
x
ˉ
  and 
�
ˉ
y
ˉ
​
  are the means of the x and y variables, respectively.
Interpretation of the result:

. If 
�
=
1
r=1, there is a perfect positive linear relationship between the variables.
. If 
�
=
−
1
r=−1, there is a perfect negative linear relationship between the variables.
. If 
�
=
0
r=0, there is no linear relationship between the variables.
Generally, if 
�
r is closer to 1 or -1, it indicates a stronger linear relationship between the variables. If 
�
r is closer to 0, it indicates a weaker linear relationship or no linear relationship.

After obtaining the Pearson correlation coefficient, you would interpret the result based on its value. For example:

. If 
�
=
0.8
r=0.8, it indicates a strong positive linear relationship, suggesting that as study time increases, final exam scores also tend to increase.
. If 
�
=
−
0.6
r=−0.6, it indicates a moderate negative linear relationship, suggesting that as study time increases, final exam scores tend to decrease.
. If 
�
=
0.1
r=0.1, it indicates a weak positive linear relationship, suggesting that there's very little correlation between study time and exam score

# %%
#Question 2

To calculate Spearman's rank correlation coefficient between the amount of sleep individuals get each night and their overall job satisfaction level, you follow these steps:

1. Assign ranks: Rank each variable separately, from lowest to highest, if there are ties, assign the average rank to tied values.

2. Calculate the differences in ranks: Find the difference between the ranks of corresponding pairs of variables.

3. Square the differences: Square each of the differences obtained in step 2.

4. Sum the squared differences: Add up all the squared differences.

5. Use the formula to calculate Spearman's rank correlation coefficient:

�
=
1
−
6
∑
�
2
�
(
�
2
−
1
)
ρ=1− 
n(n 
2
 −1)
6∑d 
2
 
​

Where:

�
ρ is Spearman's rank correlation coefficient.
�
d is the difference between the ranks of corresponding pairs.
�
n is the number of data points.
Interpretation of the result:

If 
�
=
1
ρ=1, it indicates a perfect monotonic relationship where higher ranks in one variable always correspond to higher ranks in the other, and vice versa.
If 
�
=
−
1
ρ=−1, it indicates a perfect monotonic relationship but in the opposite direction.
If 
�
=
0
ρ=0, it indicates no monotonic relationship between the variables.
Now, let's interpret the result:

A positive Spearman's rank correlation coefficient suggests that as the amount of sleep individuals get each night increases, their overall job satisfaction tends to increase as well (i.e., individuals who sleep more tend to report higher job satisfaction).
A negative Spearman's rank correlation coefficient suggests that as the amount of sleep individuals get each night decreases, their overall job satisfaction tends to decrease (i.e., individuals who sleep less tend to report lower job satisfaction).
If Spearman's rank correlation coefficient is close to 0, it suggests there's little to no monotonic relationship between the amount of sleep and overall job satisfaction levels

# %%
#Question 3

To calculate both the Pearson correlation coefficient and Spearman's rank correlation coefficient between the number of hours of exercise per week and body mass index (BMI) in your sample of adults, follow these steps:

1. Pearson Correlation Coefficient (r):

Gather data on the number of hours of exercise per week and the corresponding BMI for each of the 50 participants.
Calculate the mean of each variable.
Compute the covariance between the number of hours of exercise per week and BMI.
Calculate the standard deviation of each variable.
Use the formula for the Pearson correlation coefficient to find 'r'.
2. Spearman's Rank Correlation Coefficient (
�
ρ):

Rank each variable separately (number of hours of exercise per week and BMI) from lowest to highest.
Calculate the differences in ranks for each pair of corresponding values.
Square the differences.
Sum the squared differences.
Use the formula for Spearman's rank correlation coefficient to find 
�
ρ.
Once you have calculated both coefficients, you can compare the results.

Here are the formulas for each coefficient:
    
    Pearson Correlation Coefficient (r):

�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(x 
i
​
 − 
x
ˉ
 ) 
2
 ∑(y 
i
​
 − 
y
ˉ
​
 ) 
2
 
​
 
∑(x 
i
​
 − 
x
ˉ
 )(y 
i
​
 − 
y
ˉ
​
 )
​
 

Spearman's Rank Correlation Coefficient (
�
ρ):

�
=
1
−
6
∑
�
2
�
(
�
2
−
1
)
ρ=1− 
n(n 
2
 −1)
6∑d 
2
 
​
 

Where:

�
�
x 
i
​
  and 
�
�
y 
i
​
  are individual data points.
�
ˉ
x
ˉ
  and 
�
ˉ
y
ˉ
​
  are the means of the x and y variables, respectively.
�
d is the difference between the ranks of corresponding pairs.
�
n is the number of data points.

# %%
#Question 4

To calculate the Pearson correlation coefficient between the number of hours individuals spend watching television per day and their level of physical activity, follow these steps:
    
1. Gather data: Collect data on the number of hours individuals spend watching television per day and their corresponding level of physical activity for each of the 50 participants.

2. Compute the mean of each variable: Calculate the mean (average) of the number of hours spent watching television per day and the mean of the level of physical activity.

3. Compute the covariance: Calculate the covariance between the number of hours spent watching television per day and the level of physical activity. Covariance measures how two variables change together.

4. Compute the standard deviation of each variable: Calculate the standard deviation of the number of hours spent watching television per day and the standard deviation of the level of physical activity.

5. Use the formula for the Pearson correlation coefficient (r):
    
    
    r= 
∑(x 
i
​
 − 
x
ˉ
 ) 
2
 ∑(y 
i
​
 − 
y
ˉ
​
 ) 
2
 
​
 
∑(x 
i
​
 − 
x
ˉ
 )(y 
i
​
 − 
y
ˉ
​
 )
​
 

Where:

�
�
x 
i
​
  and 
�
�
y 
i
​
  are individual data points,
�
ˉ
x
ˉ
  and 
�
ˉ
y
ˉ
​
  are the means of the x and y variables, respectively.
Interpretation of the Pearson correlation coefficient (r):

If 
�
=
1
r=1, there is a perfect positive linear relationship between the variables.
If 
�
=
−
1
r=−1, there is a perfect negative linear relationship between the variables.
If 
�
=
0
r=0, there is no linear relationship between the variables.

# %%
#Question 5

Age (Years)    Soft Drink Preference
25             Coke
42             Pepsi
37             
19             
31             
28             Mountain Dew
              Coke
              Pepsi
              Coke

# %%
#Question 6

To calculate the Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week for the sample of 30 sales representatives, follow these steps:

1. Gather data: Collect data on the number of sales calls made per day and the number of sales made per week for each of the 30 sales representatives.

2. Compute the mean of each variable: Calculate the mean (average) of the number of sales calls made per day and the mean of the number of sales made per week.

Compute the covariance: Calculate the covariance between the number of sales calls made per day and the number of sales made per week. Covariance measures how two variables change together.

Compute the standard deviation of each variable: Calculate the standard deviation of the number of sales calls made per day and the standard deviation of the number of sales made per week.

Use the formula for the Pearson correlation coefficient (r):

�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(x 
i
​
 − 
x
ˉ
 ) 
2
 ∑(y 
i
​
 − 
y
ˉ
​
 ) 
2
 
​
 
∑(x 
i
​
 − 
x
ˉ
 )(y 
i
​
 − 
y
ˉ
​
 )
​
 

Where:

�
�
x 
i
​
  and 
�
�
y 
i
​
  are individual data points,
�
ˉ
x
ˉ
  and 
�
ˉ
y
ˉ
​
  are the means of the x and y variables, respectively.
After calculating the Pearson correlation coefficient, you can interpret the strength and direction of the relationship between the number of sales calls made per day and the number of sales made per week in your sample of 30 sales representatives.
